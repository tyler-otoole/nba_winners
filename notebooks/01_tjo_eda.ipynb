# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/game.csv', parse_dates = ['game_date'])
df.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id  game_date matchup_home wl_home  min  fgm_home  ...  reb_away  \
# 0  24600001 1946-11-01  HUS vs. NYK       L    0      25.0  ...       NaN
# 1  24600003 1946-11-02  BOM vs. PIT       W    0      20.0  ...       NaN
# 2  24600002 1946-11-02  PRO vs. BOS       W    0      21.0  ...       NaN
# 3  24600004 1946-11-02  CHS vs. NYK       W    0      21.0  ...       NaN
# 4  24600005 1946-11-02  DEF vs. WAS       L    0      10.0  ...       NaN
#
# ...

# %%
df[(df['game_date'] >= '2000-10-31') & (df['season_type'].isin(['Regular Season', 'Playoffs']))].team_name_home.unique()
# Out:
# array(['Dallas Mavericks', 'Atlanta Hawks', 'Chicago Bulls',
#        'Toronto Raptors', 'Orlando Magic', 'Vancouver Grizzlies',
#        'Utah Jazz', 'Portland Trail Blazers', 'New Jersey Nets',
#        'Golden State Warriors', 'New York Knicks', 'San Antonio Spurs',
#        'Houston Rockets', 'Seattle SuperSonics', 'Charlotte Hornets',
#        'Los Angeles Lakers', 'Miami Heat', 'Philadelphia 76ers',
#        'Boston Celtics', 'Cleveland Cavaliers', 'Denver Nuggets',
#        'Los Angeles Clippers', 'Phoenix Suns', 'Washington Wizards',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Minnesota Timberwolves', 'Sacramento Kings', 'Memphis Grizzlies',
#        'New Orleans Hornets', 'Charlotte Bobcats',
#        'New Orleans/Oklahoma City Hornets', 'Oklahoma City Thunder',
#        'Brooklyn Nets', 'New Orleans Pelicans', 'LA Clippers'],
#       dtype=object)

# %%
df[df['game_date'] >= '2000-10-31'].season_type.unique()
# Out:
# array(['Regular Season', 'Playoffs', 'All-Star', 'All Star', 'Pre Season'],
#       dtype=object)
