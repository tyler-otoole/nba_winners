# %%
import pandas as pd

# %%
df = pd.read_csv('../data/raw/game.csv', parse_dates = ['game_date'])
df.head()
# Out:
#    season_id  team_id_home team_abbreviation_home           team_name_home  \
# 0      21946    1610610035                    HUS          Toronto Huskies
# 1      21946    1610610034                    BOM        St. Louis Bombers
# 2      21946    1610610032                    PRO  Providence Steamrollers
# 3      21946    1610610025                    CHS            Chicago Stags
# 4      21946    1610610028                    DEF          Detroit Falcons
#
#     game_id  game_date matchup_home wl_home  min  fgm_home  ...  reb_away  \
# 0  24600001 1946-11-01  HUS vs. NYK       L    0      25.0  ...       NaN
# 1  24600003 1946-11-02  BOM vs. PIT       W    0      20.0  ...       NaN
# 2  24600002 1946-11-02  PRO vs. BOS       W    0      21.0  ...       NaN
# 3  24600004 1946-11-02  CHS vs. NYK       W    0      21.0  ...       NaN
# 4  24600005 1946-11-02  DEF vs. WAS       L    0      10.0  ...       NaN
#
# ...

# %%
df[df['game_date'] >= '2000-10-31'].reset_index(drop = True).sort_values(['team_abbreviation_home', 'game_date'])
# Out:
#        season_id  team_id_home team_abbreviation_home  \
# 15918      12012         12323                    ALB
# 18797      12014         12323                    ALB
# 1          22000    1610612737                    ATL
# 34         22000    1610612737                    ATL
# 102        22000    1610612737                    ATL
# ...          ...           ...                    ...
# 16115      32012    1610616834                    WST
# 16116      32012    1610616834                    WST
# 17551      32013    1610616834                    WST
# 21820      32016    1610616834                    WST
# 21821      32016    1610616834                    WST
#
#                 team_name_home   game_id  game_date matchup_home wl_home  min  \
# 15918       Berlin Alba Berlin  11200002 2012-10-06  ALB vs. DAL       L  240
# 18797       Berlin Alba Berlin  11400022 2014-10-08  ALB vs. SAS       W  240
# 1                Atlanta Hawks  20000004 2000-10-31  ATL vs. CHH       L  240
# ...
